# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
from stackapi import StackAPI
import pandas as pd

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1570492800, todate=1573171200, order='desc', sort='creation')
answers = SITE.fetch('answers', fromdate=1570492800, todate=1573171200, order='desc',sort='creation')

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['javascript',
#     'file-upload',
#     'google-cloud-functions',
#     'dropbox-api',
#     'dropzone.js'],
#    'owner': {'reputation': 45,
#     'user_id': 2402551,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/f8c2e6316c1228ff0a1018c7e41979cb?s=128&d=identicon&r=PG',
#     'display_name': 'Ian Brown',
#     'link': 'https://stackoverflow.com/users/2402551/ian-brown'},
#    'is_answered': False,
#    'view_count': 12,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1573171196,
#    'creation_date': 1573171196,
#    'question_id': 58758574,
#    'link': 'https://stackoverflow.com/questions/58758574/upload-ai-file-to-dropbox-through-firebase-functions-using-dropzone-but-no-base',
# ...

# %%
all_questions = [x.get('title') for x in questions['items']]

all_questions
# Out:
# ['Upload .AI file to Dropbox through Firebase Functions using Dropzone but no Base64 or file info included',
#  'How do i add Voice Chat Feature to already Existing Video Conference Code WebRTC Android',
#  'How to reset TYPE_STEP_COUNTER sensor on a daily basis at a specific time, instead of every reboot',
#  'Powershell Check Current Date And Folder Modified Date',
#  'how to make sc spark context global to all modules without passing to function',
#  'Ways to save RDD to S3 using pyspark',
#  'Why isn&#39;t MongoDB simple read query working?',
#  'Is there other way or using boolean ? I&#39;m trying to check if the input is a valid date',
#  'what&#39;s the correct way to create a typed Observable with RxJS?',
#  'Drawing a mixed stacked horizontal bar/line in chartjs',
#  'On Mobile why pageYOffset + clientHeight don&#39;t equal to scrollHeight?',
#  'LinearRegression on linerrud dataset',
#  'How to filter the data from excel before going to OLE DB destination',
# ...

# %%
answers
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 131,
#     'user_id': 11137679,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/38a7eff9edaa3f6705c8acd7f69c2013?s=128&d=identicon&r=PG&f=1',
#     'display_name': 'HimanshuSinha-msft',
#     'link': 'https://stackoverflow.com/users/11137679/himanshusinha-msft'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1573171190,
#    'creation_date': 1573171190,
#    'answer_id': 58758573,
#    'question_id': 58723666},
#   {'owner': {'reputation': 46584,
#     'user_id': 974731,
#     'user_type': 'registered',
#     'profile_image': 'https://www.gravatar.com/avatar/8f54ba41697411b238379022f9a6df56?s=128&d=identicon&r=PG',
#     'display_name': 'cybersam',
#     'link': 'https://stackoverflow.com/users/974731/cybersam'},
#    'is_accepted': False,
#    'score': 0,
# ...

# %%
all_answers = [x.get("answer_id") for x in answers["items"]]

all_answers
# Out:
# [58758573,
#  58758570,
#  58758568,
#  58758566,
#  58758564,
#  58758557,
#  58758555,
#  58758552,
#  58758551,
#  58758550,
#  58758549,
#  58758548,
#  58758547,
#  58758543,
#  58758541,
#  58758540,
#  58758539,
#  58758538,
#  58758537,
#  58758536,
#  58758535,
#  58758534,
#  58758527,
#  58758526,
#  58758525,
#  58758521,
#  58758520,
#  58758519,
#  58758516,
#  58758514,
#  58758513,
#  58758512,
#  58758511,
#  58758510,
#  58758509,
#  58758506,
#  58758503,
#  58758502,
#  58758501,
#  58758500,
#  58758497,
#  58758495,
#  58758494,
#  58758493,
#  58758492,
#  58758489,
#  58758488,
#  58758486,
#  58758479,
#  58758476,
#  58758475,
#  58758474,
#  58758473,
#  58758467,
#  58758466,
#  58758465,
#  58758464,
#  58758461,
#  58758457,
#  58758453,
#  58758451,
#  58758446,
#  58758445,
#  58758444,
#  58758441,
#  58758440,
#  58758433,
#  58758432,
#  58758427,
#  58758426,
#  58758425,
#  58758424,
#  58758422,
#  58758421,
#  58758420,
#  58758416,
# ...

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
voted = SITE.fetch('questions', fromdate=1473257600, todate=1573171200, tagged='python', min=5)

voted_questions= [x.get("title") for x in voted["items"]]

voted_questions
# Out:
# ['Meaning of the hidden state in Keras LSTM',
#  'Convert column text data into features using python to use for machine learning',
#  'How to convert tensorflow model (InceptionResnetV2 pb file) to pytorch model using mmconvert?',
#  'How to check existence of a folder and then remove it?',
#  'Expected view to be called with a URL keyword argument named &quot;pk&quot;',
#  'Unable to improve the mask RCNN model for document images?',
#  'Issue connecting to Dockerized Clickhouse Server with Python driver',
#  'Accuracy no longer improving after switching to Dataset',
#  'gnupg.GPG: Sorry, no terminal at all requested - can&#39;t get input',
#  'how to convert a string datetime with unknown timezone to timestamp in python',
#  'swig generated python wrapper for c code - IN_ARRAY and ARGOUT from numpy.array()',
#  'COCO api evaluation for subset of classes',
#  'Config Set min and max value for window size Kivy',
# ...

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
answer6784 = SITE.fetch("answers", ids=[6784])
answer6784
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'owner': {'reputation': 28359,
#     'user_id': 758,
#     'user_type': 'registered',
#     'accept_rate': 77,
#     'profile_image': 'https://www.gravatar.com/avatar/0b4adc19284ed0751844d610555dc6b2?s=128&d=identicon&r=PG',
#     'display_name': 'Mark Renouf',
#     'link': 'https://stackoverflow.com/users/758/mark-renouf'},
#    'is_accepted': False,
#    'score': 0,
#    'last_activity_date': 1218291583,
#    'creation_date': 1218291583,
#    'answer_id': 6784,
#    'question_id': 6778}]}

# %%
answer6473 = SITE.fetch("answers", ids=[6473])
answer6473
# Out:
# {'backoff': 0,
#  'has_more': False,
#  'page': 1,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': []}
